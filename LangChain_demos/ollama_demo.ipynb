# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
model = ChatOllama(model="deepseek-r1:14b", temperature=0)
prompt = ChatPromptTemplate.from_template("用一句话解释：{topic}")
chain = prompt | model | StrOutputParser()

print(chain.invoke({"topic": "RAG"}))
# Out:
# <think>
# 嗯，用户问的是“RAG”，我得先想一下这是什么意思。可能是指什么呢？在不同的领域里，“RAG”有不同的含义。比如，在项目管理中，RAG通常指的是红黄绿灯机制，用来评估项目的进度和风险。红色代表问题，黄色是警告，绿色表示正常。
#
# 那用户为什么会问这个呢？可能是他在工作中遇到了需要使用RAG的情况，或者是想了解这个术语的定义。他可能是一个项目经理或者团队成员，想要更好地管理项目进度和风险。
#
# 另外，“RAG”在其他领域也有不同的意思，比如在股票市场中，RAG可能代表某种指数或基金，但在这种情况下，用户更有可能是指项目管理中的红黄绿灯机制，因为这是一个比较常见的用法。
#
# 所以，我应该解释清楚RAG在项目管理中的含义，并且简明扼要地说明它的用途。这样用户就能理解它如何帮助评估和跟踪项目的健康状况了。
# </think>
#
# RAG 是 "Red, Amber, Green" 的缩写，用于项目管理中表示红灯（问题）、黄灯（警告或关注点）和绿灯（正常或进展顺利）。
